# %% [markdown]
# ### Environment setup

# %%
conda --version

# %%
conda env list # list all the environment

# %%
conda activate testenv # this is the testing environment I created

# %%
conda activate base # this is the base environment

# %%
cd ~/Documents/GitHub # go to github directory

# %%
git clone https://github.com/maple-ed/ds_2024.git  # it will clone the fork to local

# %%
git status

# %% [markdown]
# # Let me reorient myself.
#
# an easy way might be
# logic is to fork others' repo (GitHub web) then copy ssh.
# git clone others' repo. next time, you can open the forked repo directly in terminal.
#
# cd ~/Documents/GitHub/ds_2024 # go to the working directory first
# conda --version
# conda activate base # this one has jupyter notebook
# jupyter notebook # open jupyter notebook
#
# git status
# git add
# git commit
# git push # it will be synced. then you can pull request and start discussion.
