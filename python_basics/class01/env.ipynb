# %%
conda --version

# %%
conda env list # list all the environment

# %%
conda activate testenv # this is the testing environment I created

# %%
cd ~/Documents/GitHub # go to github directory

# %%
git clone https://github.com/maple-ed/ds_2024.git  # it will clone the fork to local

# %%
git status
